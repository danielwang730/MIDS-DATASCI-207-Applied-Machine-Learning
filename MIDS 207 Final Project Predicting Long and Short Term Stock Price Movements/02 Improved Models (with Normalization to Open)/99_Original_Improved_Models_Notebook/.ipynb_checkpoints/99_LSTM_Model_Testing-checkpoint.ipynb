# %% [markdown]
# # 99 LSTM Model Testing

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import heatmap

import tulipy as ti

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
from sklearn.decomposition import IncrementalPCA

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras import initializers
import keras_tuner as kt
from keras_tuner import HyperParameters

import warnings

# %% [markdown]
# ## Data Retrieval (1-minute failed from yfinance)
# We attempted to retrieve 1-minute data from yfinance, but we were unable to do so successfully (even for a short time period)

# %%
# Set Scope of Date
start_date_analyzed = '2021-01-01'
end_date_analyzed = '2025-01-01'

# Retrieve S&P 500 tickers
sp500_tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
tickers = sp500_tables[0].Symbol  # Storing just the symbols into a list
tickers_changed = sp500_tables[1]  # Including the changed tickers as well to remove survivorship bias

# Getting only the added and removed tickers
tickers_added = tickers_changed[pd.to_datetime(tickers_changed.Date.Date) >= start_date_analyzed].Added
tickers_removed = tickers_changed[pd.to_datetime(tickers_changed.Date.Date) >= start_date_analyzed].Removed

# Removing the additional added tickers
tickers = tickers[~(tickers.isin(tickers_added.Ticker))]

# Appending the removed tickers
tickers = pd.concat([tickers, tickers_removed.Ticker], ignore_index=True)

# Dropping any NA values
tickers = tickers.dropna()

# Dropping duplicates
tickers = tickers.drop_duplicates()

# Resetting the index
tickers = tickers.reset_index(drop = True)

# Filtering out problematic tickers
problematic_tickers = ['BF.B', 'BRK.B', 'GEV', 'SOLV', 'SW', 'VLTO']
filtered_tickers = [ticker for ticker in tickers if ticker not in problematic_tickers]

len(filtered_tickers)
# Out:
# 508

# %%
# One note: don't scrap too many times in a row from Yahoo Finance, or they might block you

# %%
# Getting Data for S&P500 Stocks
multi_data = yf.download(filtered_tickers, period='max', interval='1m')

# NOTE: there will be missing stocks because Yahoo Finance has delisted some of the stocks that went out of the S&P500 (like SIVB)
multi_data
# Out:
# [                       1%                       ]  5 of 508 completedFailed to get ticker 'FRC' reason: Expecting value: line 1 column 1 (char 0)
# [***                    7%                       ]  38 of 508 completedFailed to get ticker 'ALXN' reason: Expecting value: line 1 column 1 (char 0)
# [****                   9%                       ]  48 of 508 completedFailed to get ticker 'PBCT' reason: Expecting value: line 1 column 1 (char 0)
# [*********             18%                       ]  93 of 508 completedFailed to get ticker 'HFC' reason: Expecting value: line 1 column 1 (char 0)
# [*********             19%                       ]  98 of 508 completedFailed to get ticker 'ATVI' reason: Expecting value: line 1 column 1 (char 0)
# [************          26%                       ]  134 of 508 completedFailed to get ticker 'ABMD' reason: Expecting value: line 1 column 1 (char 0)
# [***************       31%                       ]  155 of 508 completedFailed to get ticker 'FBHS' reason: Expecting value: line 1 column 1 (char 0)
# [******************    38%                       ]  193 of 508 completedFailed to get ticker 'MRO' reason: Expecting value: line 1 column 1 (char 0)
# [*******************   39%                       ]  199 of 508 completedFailed to get ticker 'CTXS' reason: Expecting value: line 1 column 1 (char 0)
# [********************* 43%                       ]  216 of 508 completedFailed to get ticker 'XLNX' reason: Expecting value: line 1 column 1 (char 0)
# [**********************50%                       ]  253 of 508 completedFailed to get ticker 'GPS' reason: Expecting value: line 1 column 1 (char 0)
# [**********************52%                       ]  265 of 508 completedFailed to get ticker 'VAR' reason: Expecting value: line 1 column 1 (char 0)
# [**********************59%***                    ]  299 of 508 completedFailed to get ticker 'DISH' reason: Expecting value: line 1 column 1 (char 0)
# [**********************66%*******                ]  335 of 508 completedFailed to get ticker 'CXO' reason: Expecting value: line 1 column 1 (char 0)
# [**********************70%*********              ]  354 of 508 completedFailed to get ticker 'NLSN' reason: Expecting value: line 1 column 1 (char 0)
# [**********************71%*********              ]  359 of 508 completedFailed to get ticker 'KSU' reason: Expecting value: line 1 column 1 (char 0)
# [**********************71%*********              ]  361 of 508 completedFailed to get ticker 'FLIR' reason: Expecting value: line 1 column 1 (char 0)
# [**********************72%**********             ]  364 of 508 completedFailed to get ticker 'CERN' reason: Expecting value: line 1 column 1 (char 0)
# [**********************72%**********             ]  367 of 508 completedFailed to get ticker 'DRE' reason: Expecting value: line 1 column 1 (char 0)
# [**********************74%***********            ]  378 of 508 completedFailed to get ticker 'TWTR' reason: Expecting value: line 1 column 1 (char 0)
# [**********************75%***********            ]  379 of 508 completedFailed to get ticker 'PXD' reason: Expecting value: line 1 column 1 (char 0)
# [**********************80%*************          ]  405 of 508 completedFailed to get ticker 'SIVB' reason: Expecting value: line 1 column 1 (char 0)
# [**********************85%****************       ]  430 of 508 completedFailed to get ticker 'MXIM' reason: Expecting value: line 1 column 1 (char 0)
# [**********************91%*******************    ]  461 of 508 completedFailed to get ticker 'TIF' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  508 of 508 completed
#
# 508 Failed downloads:
# ['CBOE', 'KMX', 'CTRA', 'CNP', 'AMTM', 'MDT', 'RVTY', 'EG', 'VLO', 'LRCX', 'WAT', 'XYL', 'BIIB', 'MKC', 'NVDA', 'PCAR', 'AEE', 'NVR', 'JKHY', 'STX', 'LDOS', 'FITB', 'ADBE', 'DXCM', 'BSX', 'BAC', 'CCL', 'ALB', 'V', 'DE', 'AMCR', 'MBC', 'ILMN', 'PG', 'VRTX', 'SNA', 'SNPS', 'MMC', 'EL', 'ADI', 'NTRS', 'CPB', 'IVZ', 'MOS', 'MA', 'VRSN', 'NOC', 'FMC', 'SBNY', 'AAPL', 'CHTR', 'PEG', 'DVA', 'NWSA', 'HST', 'BAX', 'CRM', 'LEG', 'RSG', 'CHD', 'ETN', 'ECL', 'HSIC', 'CB', 'FOXA', 'COST', 'ORCL', 'GPN', 'EA', 'NSC', 'UAA', 'TER', 'OGN', 'GM', 'GOOG', 'FANG', 'CAH', 'NWS', 'KLAC', 'AES', 'MCK', 'GLW', 'RL', 'T', 'PFG', 'NDAQ', 'LYV', 'MO', 'ALK', 'FOX', 'PVH', 'F', 'WHR', 'GS', 'AZO', 'A', 'DOV', 'AFL', 'DHI', 'UNP', 'IFF', 'AAP', 'ETSY', 'DG', 'TFC', 'STZ', 'HON', 'CMS', 'HAL', 'EIX', 'KO', 'WY', 'KMI', 'WTW', 'ADP', 'EXC', 'BEN', 'DRI', 'AWK', 'BLK', 'BXP', 'AMP', 'IRM', 'TEL', 'ALLE', 'ABT', 'LLY', 'BMY', 'EMN', 'VTR', 'UHS', 'BIO', 'ETR', 'ROP', 'HUM', 'MU', 'VNT', 'CMG', 'SBAC', 'APTV', 'RJF', 'GPC', 'LKQ', 'ABBV', 'BKR', 'VTRS', 'EBAY', 'GL', 'CE', 'IPGP', 'AIG', 'OKE', 'DGX', 'L', 'ROST', 'AEP', 'APA', 'ES', 'ROL', 'TSLA', 'CDW', 'ELV', 'DAL', 'WAB', 'DHR', 'IEX', 'DLR', 'CARR', 'PPG', 'TSCO', 'RCL', 'PLD', 'AVGO', 'XOM', 'PAYX', 'TYL', 'ATO', 'AME', 'MCD', 'HCA', 'LVS', 'LIN', 'MNST', 'PGR', 'UNM', 'TROW', 'LOW', 'TTWO', 'FTV', 'MET', 'RTX', 'VNO', 'EQIX', 'ZION', 'MSI', 'IQV', 'FTNT', 'ALL', 'PYPL', 'NWL', 'PNC', 'VFC', 'TJX', 'SPG', 'WMT', 'MAA', 'ESS', 'BK', 'AIZ', 'NOV', 'OXY', 'PNR', 'PKG', 'VZ', 'CLX', 'UNH', 'CFG', 'HIG', 'TPR', 'ISRG', 'HLT', 'VMC', 'TRV', 'SJM', 'ANSS', 'TSN', 'CSCO', 'AAL', 'KIM', 'MTB', 'UDR', 'WM', 'OTIS', 'TDG', 'SEE', 'NI', 'KEY', 'ED', 'IPG', 'PM', 'FI', 'MTD', 'EXPE', 'CBRE', 'K', 'NEE', 'PRGO', 'CINF', 'GOOGL', 'KHC', 'DOW', 'CF', 'CTVA', 'MAS', 'MCO', 'KMB', 'WU', 'QCOM', 'DPZ', 'UAL', 'TFX', 'LNT', 'AMAT', 'DUK', 'CAT', 'ROK', 'YUM', 'BWA', 'PENN', 'HRL', 'CPRT', 'LMT', 'WEC', 'ICE', 'LNC', 'NUE', 'EQR', 'PSX', 'CSX', 'SHW', 'INCY', 'LH', 'NCLH', 'PRU', 'SLB', 'TGT', 'CMCSA', 'CTLT', 'ODFL', 'CAG', 'LYB', 'INTU', 'TXT', 'CVX', 'SBUX', 'RF', 'EXR', 'TMO', 'GILD', 'GWW', 'AMD', 'JPM', 'PNW', 'AVB', 'EOG', 'HBI', 'AKAM', 'NEM', 'MLM', 'COO', 'TT', 'VRSK', 'IDXX', 'AXP', 'WMB', 'DTE', 'SYF', 'AMZN', 'BALL', 'MMM', 'CCI', 'AMGN', 'HSY', 'EMR', 'ZTS', 'COF', 'MSFT', 'HPE', 'XRAY', 'DVN', 'LHX', 'BKNG', 'URI', 'HAS', 'UA', 'JNJ', 'FTI', 'NKE', 'SRE', 'META', 'HPQ', 'DFS', 'PWR', 'TXN', 'FE', 'PEP', 'QRVO', 'ADSK', 'BBWI', 'JNPR', 'STT', 'CVS', 'SYK', 'HBAN', 'IR', 'FAST', 'SCHW', 'HD', 'FCX', 'PAYC', 'HWM', 'XRX', 'MRK', 'CI', 'ADM', 'SPGI', 'IBM', 'RMD', 'BA', 'CHRW', 'KEYS', 'CNC', 'WDC', 'SYY', 'JCI', 'EVRG', 'COP', 'POOL', 'XEL', 'RHI', 'CL', 'CTAS', 'CTSH', 'STE', 'PARA', 'CME', 'PH', 'ANET', 'ZBRA', 'CMI', 'AON', 'DLTR', 'SWK', 'REGN', 'ULTA', 'PPL', 'AOS', 'BDX', 'AJG', 'SLG', 'DXC', 'C', 'HOLX', 'NTAP', 'EXPD', 'EFX', 'USB', 'REG', 'JBHT', 'INTC', 'MHK', 'MS', 'EW', 'AVY', 'PFE', 'NRG', 'FDX', 'APH', 'SWKS', 'LW', 'CMA', 'MAR', 'MSCI', 'ORLY', 'PHM', 'ZBH', 'FRT', 'WYNN', 'GD', 'WBA', 'COR', 'FLS', 'WST', 'GEN', 'WRB', 'NOW', 'DAY', 'ITW', 'ACN', 'CPAY', 'IP', 'MKTX', 'MPC', 'WBD', 'MGM', 'BR', 'IT', 'DIS', 'MDLZ', 'UPS', 'FFIV', 'PSA', 'CDNS', 'INFO', 'LUMN', 'TMUS', 'MCHP', 'OMC', 'BBY', 'NFLX', 'ARE', 'ALGN', 'LUV', 'FIS', 'HII', 'TAP', 'APD', 'DOC', 'WFC', 'GIS', 'WELL', 'LEN', 'DD', 'GE', 'AMT', 'KR', 'SEDG', 'GRMN', 'HES', 'TDY']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# ['FRC', 'ALXN', 'PBCT', 'HFC', 'ATVI', 'ABMD', 'FBHS', 'MRO', 'CTXS', 'XLNX', 'GPS', 'VAR', 'DISH', 'CXO', 'NLSN', 'KSU', 'FLIR', 'CERN', 'DRE', 'TWTR', 'PXD', 'SIVB', 'MXIM', 'TIF']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['O']: JS%ticker%NDecodeError('Expecting value: line 1 column 1 (char 0)')
# ['SO']: J%ticker%NDecodeError('Expecting value: line 1 column 1 (char 0)')
# ['D']: JSON%ticker%ecodeError('Expecting value: line 1 column 1 (char 0)')
# ['J']: %ticker%SONDecodeError('Expecting value: line 1 column 1 (char 0)')
# Empty DataFrame
# Columns: [(Adj Close, A), (Adj Close, AAL), (Adj Close, AAP), (Adj Close, AAPL), (Adj Close, ABBV), (Adj Close, ABMD), (Adj Close, ABT), (Adj Close, ACN), (Adj Close, ADBE), (Adj Close, ADI), (Adj Close, ADM), (Adj Close, ADP), (Adj Close, ADSK), (Adj Close, AEE), (Adj Close, AEP), (Adj Close, AES), (Adj Close, AFL), (Adj Close, AIG), (Adj Close, AIZ), (Adj Close, AJG), (Adj Close, AKAM), (Adj Close, ALB), (Adj Close, ALGN), (Adj Close, ALK), (Adj Close, ALL), (Adj Close, ALLE), (Adj Close, ALXN), (Adj Close, AMAT), (Adj Close, AMCR), (Adj Close, AMD), (Adj Close, AME), (Adj Close, AMGN), (Adj Close, AMP), (Adj Close, AMT), (Adj Close, AMTM), (Adj Close, AMZN), (Adj Close, ANET), (Adj Close, ANSS), (Adj Close, AON), (Adj Close, AOS), (Adj Close, APA), (Adj Close, APD), (Adj Close, APH), (Adj Close, APTV), (Adj Close, ARE), (Adj Close, ATO), (Adj Close, ATVI), (Adj Close, AVB), (Adj Close, AVGO), (Adj Close, AVY), (Adj Close, AWK), (Adj Close, AXP), (Adj Close, AZO), (Adj Close, BA), (Adj Close, BAC), (Adj Close, BALL), (Adj Close, BAX), (Adj Close, BBWI), (Adj Close, BBY), (Adj Close, BDX), (Adj Close, BEN), (Adj Close, BIIB), (Adj Close, BIO), (Adj Close, BK), (Adj Close, BKNG), (Adj Close, BKR), (Adj Close, BLK), (Adj Close, BMY), (Adj Close, BR), (Adj Close, BSX), (Adj Close, BWA), (Adj Close, BXP), (Adj Close, C), (Adj Close, CAG), (Adj Close, CAH), (Adj Close, CARR), (Adj Close, CAT), (Adj Close, CB), (Adj Close, CBOE), (Adj Close, CBRE), (Adj Close, CCI), (Adj Close, CCL), (Adj Close, CDNS), (Adj Close, CDW), (Adj Close, CE), (Adj Close, CERN), (Adj Close, CF), (Adj Close, CFG), (Adj Close, CHD), (Adj Close, CHRW), (Adj Close, CHTR), (Adj Close, CI), (Adj Close, CINF), (Adj Close, CL), (Adj Close, CLX), (Adj Close, CMA), (Adj Close, CMCSA), (Adj Close, CME), (Adj Close, CMG), (Adj Close, CMI), ...]
# Index: []
#
# [0 rows x 3048 columns]

# %% [markdown]
# ## LSTM Testing

# %% [markdown]
# From the following link: https://www.geeksforgeeks.org/long-short-term-memory-lstm-rnn-in-tensorflow/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Getting data and scaling it
data = pd.read_csv('monthly_milk_production.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
production = data['Production'].astype(float).values.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(production)

# %%
scaled_data.shape
# Out:
# (168, 1)

# %%
window_size = 12
X = []
y = []
target_dates = data.index[window_size:]

for i in range(window_size, len(scaled_data)):
    X.append(scaled_data[i - window_size:i, 0])
    y.append(scaled_data[i, 0])

X = np.array(X)
y = np.array(y)

X_train, X_test, y_train, y_test, dates_train, dates_test = train_test_split(
    X, y, target_dates, test_size=0.2, shuffle=False
)

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
X[0]
# Out:
# array([0.08653846, 0.01923077, 0.20913462, 0.24759615, 0.41826923,
#        0.34615385, 0.20913462, 0.11057692, 0.03605769, 0.05769231,
#        0.        , 0.06971154])

# %%
X[1]
# Out:
# array([0.01923077, 0.20913462, 0.24759615, 0.41826923, 0.34615385,
#        0.20913462, 0.11057692, 0.03605769, 0.05769231, 0.        ,
#        0.06971154, 0.11298077])

# %%
X_train.shape
# Out:
# (124, 12, 1)

# %%
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=128))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 14, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 14, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 198,273 (774.50 KB)
#  Trainable params: 198,273 (774.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1)

predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions).flatten()
y_test = scaler.inverse_transform(y_test.reshape(-1,1)).flatten()

rmse = np.sqrt(np.mean((y_test - predictions)**2))
print(f'RMSE: {rmse:.2f}')
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.1801 - val_loss: 0.0296
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0393 - val_loss: 0.0468
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0317 - val_loss: 0.0609
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0347 - val_loss: 0.0599
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0292 - val_loss: 0.0293
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0279 - val_loss: 0.0287
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0301 - val_loss: 0.0265
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0252 - val_loss: 0.0364
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0266 - val_loss: 0.0377
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0270 - val_loss: 0.0270
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0253 - val_loss: 0.0253
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0254 - val_loss: 0.0258
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0238 - val_loss: 0.0276
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0216 - val_loss: 0.0278
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0254 - val_loss: 0.0252
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0211 - val_loss: 0.0265
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0231 - val_loss: 0.0245
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0213 - val_loss: 0.0236
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0205 - val_loss: 0.0229
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0220 - val_loss: 0.0230
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0209 - val_loss: 0.0215
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0190 - val_loss: 0.0214
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0177 - val_loss: 0.0203
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0191 - val_loss: 0.0193
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0169 - val_loss: 0.0185
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0181 - val_loss: 0.0164
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0172 - val_loss: 0.0156
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0150 - val_loss: 0.0134
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0118 - val_loss: 0.0134
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0144 - val_loss: 0.0110
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0113 - val_loss: 0.0110
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0106 - val_loss: 0.0101
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0126 - val_loss: 0.0065
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0102 - val_loss: 0.0384
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0187 - val_loss: 0.0059
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0097 - val_loss: 0.0168
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0100 - val_loss: 0.0075
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0101 - val_loss: 0.0113
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0098 - val_loss: 0.0055
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0100 - val_loss: 0.0058
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0110 - val_loss: 0.0060
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0086 - val_loss: 0.0054
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0095 - val_loss: 0.0058
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0070 - val_loss: 0.0037
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0070 - val_loss: 0.0050
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0059 - val_loss: 0.0032
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0067 - val_loss: 0.0097
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0050 - val_loss: 0.0029
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0052 - val_loss: 0.0028
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040 - val_loss: 0.0027
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0045 - val_loss: 0.0025
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0045 - val_loss: 0.0074
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0054 - val_loss: 0.0045
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0036 - val_loss: 0.0056
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0033 - val_loss: 0.0055
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0045 - val_loss: 0.0062
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0044 - val_loss: 0.0030
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0051 - val_loss: 0.0084
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0046 - val_loss: 0.0082
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0051 - val_loss: 0.0089
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0085 - val_loss: 0.0208
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0046 - val_loss: 0.0035
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - val_loss: 0.0080
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0043 - val_loss: 0.0037
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - val_loss: 0.0063
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0055 - val_loss: 0.0077
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0030 - val_loss: 0.0062
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0032 - val_loss: 0.0049
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0042 - val_loss: 0.0036
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0032 - val_loss: 0.0083
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0036 - val_loss: 0.0057
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037 - val_loss: 0.0139
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0050 - val_loss: 0.0078
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0032 - val_loss: 0.0041
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0036 - val_loss: 0.0069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# RMSE: 35.62

# %%
plt.figure(figsize=(12, 6))
plt.plot(dates_test, y_test, label='Actual Production')
plt.plot(dates_test, predictions, label='Predicted Production')
plt.title('Actual vs Predicted Milk Production')
plt.xlabel('Date')
plt.ylabel('Production (pounds per cow)')
plt.legend()
plt.show()

# %% [markdown]
# # Conclusions from LSTM Model Testing
# This initial testing was crucial for our understanding of the LSTM model. We saw the need to convert our data into a series format, and we saw how important they were for future predictions. We will attempt integrating something similar when we actually work with our stock data.
